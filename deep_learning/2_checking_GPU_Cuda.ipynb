# %% [markdown]
# И так... Чтобы проверить работу видеокарт, необходимо сделать следующее:
#
# 1. Откройте вкладку "Среда выполнения"
# 2. Выберите строчку "Смена среды выполнения"
# 3. Выберите подходящий для вас вариант либо CPU, GPU T4 (работа с видеокартами NVIDIA Tesla T4) либо TPU. Больше опций доступно по подписке и на них можно посмотреть, нажав на знак вопроса.
#
# ![image.png](data:image/png;base64,...)
#
# Далее, чтобы убедиться что все работает правильно, прогоните следующую команду:

# %%
# !nvidia-smi
# Out:
# Sat Sep 28 19:43:42 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# Чтобы убедиться, что CUDA установлена, можете проверить следующую команду.
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# Чтобы проверить, что PyTorch или Tensor Flow используют ГПУ в Коллабе используйте следующие команды:
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# Либо
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'
